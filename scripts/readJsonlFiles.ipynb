# %%
import numpy as np
import pandas as pd
import json

# %%
# Taken from https://galea.medium.com/how-to-love-jsonl-using-json-line-format-in-your-workflow-b6884f65175b
def dump_jsonl(data, output_path, append=False):
    """
    Write list of objects to a JSON lines file.
    """
    mode = 'a+' if append else 'w'
    with open(output_path, mode, encoding='utf-8') as f:
        for line in data:
            json_record = json.dumps(line, ensure_ascii=False)
            f.write(json_record + '\n')
    print('Wrote {} records to {}'.format(len(data), output_path))

def load_jsonl(input_path) -> list:
    """
    Read list of objects from a JSON lines file.
    """
    data = []
    with open(input_path, 'r', encoding='utf-8') as f:
        for line in f:
            data.append(json.loads(line.rstrip('\n|\r')))
    print('Loaded {} records from {}'.format(len(data), input_path))
    return data

# %%
filename = '../scripts/test.jsonl';

# %%
test=load_jsonl(filename)
# Out:
# Loaded 0 records from ../scripts/test.jsonl

# %%
test
# Out:
# [{'attachments': {'media_keys': ['7_1212295980726530048'],
#    'media': [{'media_key': '7_1212295980726530048',
#      'preview_image_url': 'https://pbs.twimg.com/ext_tw_video_thumb/1212295980726530048/pu/img/sR9zNp6-WdurBui1.jpg',
#      'duration_ms': 139933,
#      'public_metrics': {'view_count': 3581},
#      'height': 368,
#      'width': 640,
#      'type': 'video'}]},
#   'created_at': '2020-01-01T08:54:35.000Z',
#   'entities': {'urls': [{'start': 272,
#      'end': 295,
#      'url': 'https://t.co/aftyuoTQjo',
#      'expanded_url': 'https://twitter.com/JJDiazMachuca/status/1212296044412887041/video/1',
#      'display_url': 'pic.twitter.com/aftyuoTQjo'}],
#    'hashtags': [{'start': 130, 'end': 137, 'tag': 'Sayula'},
#     {'start': 139, 'end': 147, 'tag': 'Jalisco'}]},
#   'id': '1212296044412887041',
#   'reply_settings': 'everyone',
#   'conversation_id': '1212296044412887041',
#   'lang': 'es',
#   'source': 'Twitter for iPhone',
# ...

# %%
print(test[1]["created_at"])
print(test[1]["author_id"])
# print(test[1]["source"])
print(test[1]["text"])
print(test[1]["author"]["username"])
# print(test[1]["user"]['description'])
# Out:
# 2020-01-01T07:43:44.000Z
# 914567349121851392
# @abrahamendieta Por mi aquí quedate bienvenido y ahora resulta que un español nos ayuda a que ya no sigan saqueando el país ya que hay muchos mexicanos que lo saquearon como en la conquista que ironías de la vida
# JesusMa01896533

# %%
for i in range(1102):
    print("Tweet",i,test[i]["author_id"],test[i]["text"])
# Out:
# Tweet 0 1005155561313308672 Por eso estamos tan jodidos con la inseguridad en el país...ni entre ellos se ponen de acuerdo para proteger a los Mexicanos.
# En #Sayula, #Jalisco la policía municipal, obstruyendo el paso al ejército Mexicano.
# Si son corruptos, ¿por qué los militares no los detuvieron? https://t.co/aftyuoTQjo
# Tweet 1 914567349121851392 @abrahamendieta Por mi aquí quedate bienvenido y ahora resulta que un español nos ayuda a que ya no sigan saqueando el país ya que hay muchos mexicanos que lo saquearon como en la conquista que ironías de la vida
# Tweet 2 1201061603292016640 @MarkoCortes Muchas gracias por sus buenos deseos, creo que para los mexicanos nunca habíamos tenido un año como el 2019 y los venideros serán mejores, sin corrupción en nuestro gobierno, y caheran más cabezas, de políticos tatas y vende patrias y traidores,
# ...
